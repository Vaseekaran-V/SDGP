# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
data = pd.read_csv(r'..\Datasets\Parkinsons Processed Training - Only Vowels - Sri Lankan.csv', header = 0)
data
# Out:
#      Subject Id  Jitter(local)  Jitter(local, absolute)  Jitter (rap)  \
# 0             1        0.01488                 0.000090       0.00900
# 1             1        0.00728                 0.000038       0.00353
# 2             1        0.00472                 0.000031       0.00224
# 3             2        0.00427                 0.000034       0.00243
# 4             2        0.00844                 0.000069       0.00509
# ..          ...            ...                      ...           ...
# 115          39        0.00601                 0.000031       0.00316
# 116          39        0.00382                 0.000017       0.00169
# 117          40        0.00471                 0.000034       0.00186
# 118          40        0.04319                 0.000317       0.02774
# 119          40        0.01543                 0.000103       0.01004
#
#      Jitter (ppq5)  Jitter (ddp)  Shimmer (local)  Shimmer (local, db)  \
# ...

# %%
print(type(data['Jitter(local)']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(data['Jitter(local)'].values)
# Out:
# [0.01488 0.00728 0.00472 0.00427 0.00844 0.01264 0.00771 0.01497 0.01542
#  0.00607 0.00287 0.00585 0.00695 0.00395 0.00883 0.00777 0.0074  0.00506
#  0.0063  0.00605 0.00988 0.00342 0.00265 0.00447 0.00449 0.00258 0.00296
#  0.00888 0.00649 0.00717 0.00342 0.01005 0.00411 0.01761 0.01841 0.01438
#  0.00347 0.00546 0.00324 0.00346 0.00195 0.00442 0.00449 0.00464 0.00561
#  0.00669 0.00661 0.00976 0.00291 0.00311 0.00509 0.02106 0.03734 0.03074
#  0.01046 0.00773 0.01084 0.00685 0.00627 0.01565 0.00792 0.004   0.00813
#  0.00418 0.00341 0.00567 0.02531 0.01506 0.00814 0.00553 0.00806 0.00482
#  0.01145 0.00674 0.00603 0.00792 0.0094  0.00652 0.00532 0.00391 0.00591
#  0.00209 0.0019  0.00366 0.00918 0.00384 0.00343 0.00549 0.00371 0.0037
#  0.00689 0.01091 0.01763 0.01538 0.02184 0.02192 0.00388 0.00464 0.0055
#  0.00826 0.00636 0.01251 0.00424 0.00281 0.00589 0.00376 0.00208 0.01508
#  0.00289 0.00291 0.0041  0.00526 0.00253 0.0252  0.00613 0.00601 0.00382
# ...

# %%
plot_x = data['Jitter(local)']
plot_y = data['Jitter(local, absolute)']

# %%
plt.plot(plot_x, plot_y, 'o')
plt.show()
